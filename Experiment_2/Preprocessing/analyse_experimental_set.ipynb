# %%
import pandas as pd
import os
from dotenv import load_dotenv
from pathlib import Path
env_path = Path('../..') / 'config.env'
load_dotenv(dotenv_path=env_path)
dataset_dir = os.getenv("dataset_directory")

# %%
dataset = 'bx' # ml, mlhd, or bx
year = 2013 # Only for mlhd dataset
filtered = True

# %%
if dataset == 'ml':
    data_dir = dataset_dir + f'/processed/ml_rec{"_filtered" if filtered else ""}'
elif dataset == 'mlhd':
    data_dir = dataset_dir + f'/processed/mlhd_rec{"_filtered" if filtered else ""}_{year}'
elif dataset == 'bx':
    data_dir = dataset_dir + f'/processed/bx_rec{"_filtered" if filtered else ""}'

# %%
train_path = data_dir + f'/train.tsv'
validation_path = data_dir + f'/validation.tsv'
test_path = data_dir + f'/test.tsv'
user_info_path = data_dir + f'/user_info.tsv'

column_names = ['user_id', 'track_id', 'count'] if dataset == 'bx' else ['user_id', 'track_id', 'count', 'timestamp']

train = pd.read_csv(train_path, sep='\t', header=None, names=column_names)
validation = pd.read_csv(validation_path, sep='\t', header=None, names=column_names)
test = pd.read_csv(test_path, sep='\t', header=None, names=column_names)

users = pd.read_csv(user_info_path, sep='\t')


train = pd.merge(train, users, on='user_id', how='inner')
validation = pd.merge(validation, users, on='user_id', how='inner')
test = pd.merge(test, users, on='user_id', how='inner')

# %%
len_interactions = len(train) + len(validation) + len(test)

print(f'Train set: {len(train)} rows; {len(train) / len_interactions * 100:.2f}% of total interactions')
print(f'Validation set: {len(validation)} rows; {len(validation) / len_interactions * 100:.2f}% of total interactions')
print(f'Test set: {len(test)} rows; {len(test) / len_interactions * 100:.2f}% of total interactions')

print(f'Train set: {len(train["user_id"].unique())} unique users')
print(f'Validation set: {len(validation["user_id"].unique())} unique users')
print(f'Test set: {len(test["user_id"].unique())} unique users')

train_interactions_per_user = train.groupby('user_id').size()
print(f'Train set: {train_interactions_per_user.mean()} average interactions per user')

validation_interactions_per_user = validation.groupby('user_id').size()
print(f'Validation set: {validation_interactions_per_user.mean()} average interactions per user')

test_interactions_per_user = test.groupby('user_id').size()
print(f'Test set: {test_interactions_per_user.mean()} average interactions per user')
# Out:
# Train set: 144854 rows; 58.96% of total interactions
# Validation set: 46770 rows; 19.04% of total interactions
# Test set: 54037 rows; 22.00% of total interactions
# Train set: 6950 unique users
# Validation set: 6950 unique users
# Test set: 6950 unique users
# Train set: 20.84230215827338 average interactions per user
# Validation set: 6.729496402877698 average interactions per user
# Test set: 7.775107913669065 average interactions per user

# %%
age_identifier = 'age_at_listen' if dataset == 'mlhd' else 'age'
train_interactions_per_age_group = train.groupby(age_identifier)

validation_interactions_per_age_group = validation.groupby(age_identifier)

test_interactions_per_age_group = test.groupby(age_identifier)

# %%
empty_train_profiles = users[users['user_id'].isin(train['user_id']) == False]
empty_validation_profiles = users[users['user_id'].isin(validation['user_id']) == False]
empty_test_profiles = users[users['user_id'].isin(test['user_id']) == False]

print(f'Train set: {len(empty_train_profiles)} users with empty profiles')
print(f'Validation set: {len(empty_validation_profiles)} users with empty profiles')
print(f'Test set: {len(empty_test_profiles)} users with empty profiles')

small_user_profiles = train_interactions_per_user[train_interactions_per_user < 10]
print(f'Train set: {len(small_user_profiles)} users with less than 10 interactions')
small_user_profiles = validation_interactions_per_user[validation_interactions_per_user < 10]
print(f'Validation set: {len(small_user_profiles)} users with less than 10 interactions')
small_user_profiles = test_interactions_per_user[test_interactions_per_user < 10]
print(f'Test set: {len(small_user_profiles)} users with less than 10 interactions')
# Out:
# Train set: 37 users with empty profiles
# Validation set: 37 users with empty profiles
# Test set: 37 users with empty profiles
# Train set: 4401 users with less than 10 interactions
# Validation set: 5951 users with less than 10 interactions
# Test set: 5826 users with less than 10 interactions

# %%
print("Train set")
for age, group in train_interactions_per_age_group:
    print(f'Age: {age}')
    print(f'Number of user profiles: {len(group["user_id"].unique())}')
    print(f'Average items in user profile: {group.groupby("user_id").size().mean()}')
    small_user_profiles = group.groupby("user_id").size()[group.groupby("user_id").size() < 10]
    print(f'Users with less than 10 interactions: {len(small_user_profiles)}')
print()
print()

print("Validation set")
for age, group in validation_interactions_per_age_group:
    print(f'Age: {age}')
    print(f'Number of user profiles: {len(group["user_id"].unique())}')
    print(f'Average items in user profile: {group.groupby("user_id").size().mean()}')
    small_user_profiles = group.groupby("user_id").size()[group.groupby("user_id").size() < 10]
    print(f'Users with less than 10 interactions: {len(small_user_profiles)}')
print()
print()   

print("Test set")
for age, group in test_interactions_per_age_group:
    print(f'Age: {age}')
    print(f'Number of user profiles: {len(group["user_id"].unique())}')
    print(f'Average items in user profile: {group.groupby("user_id").size().mean()}')
    small_user_profiles = group.groupby("user_id").size()[group.groupby("user_id").size() < 10]
    print(f'Users with less than 10 listening events: {len(small_user_profiles)}')
print()
print()
# Out:
# Train set
# Age: 12.0
# Number of user profiles: 15
# Average items in user profile: 10.6
# Users with less than 10 interactions: 10
# Age: 13.0
# Number of user profiles: 23
# Average items in user profile: 8.347826086956522
# Users with less than 10 interactions: 15
# Age: 14.0
# Number of user profiles: 44
# Average items in user profile: 15.75
# Users with less than 10 interactions: 32
# Age: 15.0
# Number of user profiles: 47
# Average items in user profile: 11.106382978723405
# Users with less than 10 interactions: 33
# Age: 16.0
# Number of user profiles: 53
# Average items in user profile: 9.09433962264151
# Users with less than 10 interactions: 39
# Age: 17.0
# Number of user profiles: 84
# Average items in user profile: 11.94047619047619
# Users with less than 10 interactions: 62
# Age: 18.0
# Number of user profiles: 109
# Average items in user profile: 16.376146788990827
# Users with less than 10 interactions: 75
# Age: 19.0
# Number of user profiles: 73
# Average items in user profile: 12.0
# Users with less than 10 interactions: 52
# Age: 20.0
# Number of user profiles: 99
# Average items in user profile: 11.232323232323232
# Users with less than 10 interactions: 69
# Age: 21.0
# Number of user profiles: 119
# Average items in user profile: 16.100840336134453
# Users with less than 10 interactions: 86
# Age: 22.0
# Number of user profiles: 121
# Average items in user profile: 17.735537190082646
# Users with less than 10 interactions: 79
# Age: 23.0
# Number of user profiles: 205
# Average items in user profile: 16.75121951219512
# Users with less than 10 interactions: 127
# Age: 24.0
# Number of user profiles: 193
# Average items in user profile: 19.202072538860104
# Users with less than 10 interactions: 110
# Age: 25.0
# Number of user profiles: 221
# Average items in user profile: 19.307692307692307
# Users with less than 10 interactions: 126
# Age: 26.0
# Number of user profiles: 240
# Average items in user profile: 18.0875
# Users with less than 10 interactions: 145
# Age: 27.0
# Number of user profiles: 219
# Average items in user profile: 18.60730593607306
# Users with less than 10 interactions: 134
# Age: 28.0
# Number of user profiles: 236
# Average items in user profile: 21.470338983050848
# Users with less than 10 interactions: 140
# Age: 29.0
# Number of user profiles: 304
# Average items in user profile: 20.76644736842105
# Users with less than 10 interactions: 189
# Age: 30.0
# Number of user profiles: 240
# Average items in user profile: 23.429166666666667
# Users with less than 10 interactions: 146
# Age: 31.0
# Number of user profiles: 231
# Average items in user profile: 20.848484848484848
# Users with less than 10 interactions: 143
# Age: 32.0
# Number of user profiles: 255
# Average items in user profile: 22.258823529411764
# Users with less than 10 interactions: 154
# Age: 33.0
# Number of user profiles: 247
# Average items in user profile: 31.37246963562753
# Users with less than 10 interactions: 144
# Age: 34.0
# Number of user profiles: 250
# Average items in user profile: 19.836
# Users with less than 10 interactions: 158
# Age: 35.0
# Number of user profiles: 227
# Average items in user profile: 17.325991189427313
# Users with less than 10 interactions: 147
# Age: 36.0
# Number of user profiles: 219
# Average items in user profile: 25.410958904109588
# Users with less than 10 interactions: 130
# Age: 37.0
# Number of user profiles: 202
# Average items in user profile: 22.50990099009901
# Users with less than 10 interactions: 124
# Age: 38.0
# Number of user profiles: 198
# Average items in user profile: 23.792929292929294
# Users with less than 10 interactions: 124
# Age: 39.0
# Number of user profiles: 164
# Average items in user profile: 20.646341463414632
# Users with less than 10 interactions: 108
# Age: 40.0
# Number of user profiles: 152
# Average items in user profile: 18.973684210526315
# Users with less than 10 interactions: 91
# Age: 41.0
# Number of user profiles: 161
# Average items in user profile: 20.937888198757765
# Users with less than 10 interactions: 103
# Age: 42.0
# Number of user profiles: 133
# Average items in user profile: 14.210526315789474
# Users with less than 10 interactions: 85
# Age: 43.0
# Number of user profiles: 156
# Average items in user profile: 25.53205128205128
# Users with less than 10 interactions: 95
# Age: 44.0
# Number of user profiles: 134
# Average items in user profile: 29.567164179104477
# Users with less than 10 interactions: 86
# Age: 45.0
# Number of user profiles: 114
# Average items in user profile: 19.719298245614034
# Users with less than 10 interactions: 78
# Age: 46.0
# Number of user profiles: 111
# Average items in user profile: 29.333333333333332
# Users with less than 10 interactions: 61
# Age: 47.0
# Number of user profiles: 109
# Average items in user profile: 34.92660550458716
# Users with less than 10 interactions: 70
# Age: 48.0
# Number of user profiles: 93
# Average items in user profile: 17.204301075268816
# Users with less than 10 interactions: 64
# Age: 49.0
# Number of user profiles: 117
# Average items in user profile: 25.632478632478634
# Users with less than 10 interactions: 69
# Age: 50.0
# Number of user profiles: 100
# Average items in user profile: 15.34
# Users with less than 10 interactions: 67
# Age: 51.0
# Number of user profiles: 91
# Average items in user profile: 33.84615384615385
# Users with less than 10 interactions: 51
# Age: 52.0
# Number of user profiles: 94
# Average items in user profile: 31.382978723404257
# Users with less than 10 interactions: 66
# Age: 53.0
# Number of user profiles: 91
# Average items in user profile: 14.824175824175825
# Users with less than 10 interactions: 64
# Age: 54.0
# Number of user profiles: 101
# Average items in user profile: 21.316831683168317
# Users with less than 10 interactions: 71
# Age: 55.0
# Number of user profiles: 75
# Average items in user profile: 15.626666666666667
# Users with less than 10 interactions: 44
# Age: 56.0
# Number of user profiles: 73
# Average items in user profile: 18.041095890410958
# Users with less than 10 interactions: 53
# Age: 57.0
# Number of user profiles: 102
# Average items in user profile: 16.598039215686274
# Users with less than 10 interactions: 70
# Age: 58.0
# Number of user profiles: 72
# Average items in user profile: 31.819444444444443
# Users with less than 10 interactions: 48
# Age: 59.0
# Number of user profiles: 55
# Average items in user profile: 9.8
# Users with less than 10 interactions: 39
# Age: 60.0
# Number of user profiles: 45
# Average items in user profile: 15.533333333333333
# Users with less than 10 interactions: 32
# Age: 61.0
# Number of user profiles: 44
# Average items in user profile: 22.931818181818183
# Users with less than 10 interactions: 29
# Age: 62.0
# Number of user profiles: 40
# Average items in user profile: 32.225
# Users with less than 10 interactions: 31
# Age: 63.0
# Number of user profiles: 28
# Average items in user profile: 21.464285714285715
# Users with less than 10 interactions: 16
# Age: 64.0
# Number of user profiles: 21
# Average items in user profile: 5.904761904761905
# Users with less than 10 interactions: 17
#
#
# Validation set
# Age: 12.0
# Number of user profiles: 15
# Average items in user profile: 3.2666666666666666
# Users with less than 10 interactions: 13
# Age: 13.0
# Number of user profiles: 23
# Average items in user profile: 2.608695652173913
# Users with less than 10 interactions: 22
# Age: 14.0
# Number of user profiles: 44
# Average items in user profile: 5.0227272727272725
# Users with less than 10 interactions: 39
# Age: 15.0
# Number of user profiles: 47
# Average items in user profile: 3.4893617021276597
# Users with less than 10 interactions: 42
# Age: 16.0
# Number of user profiles: 53
# Average items in user profile: 2.830188679245283
# Users with less than 10 interactions: 51
# Age: 17.0
# Number of user profiles: 84
# Average items in user profile: 3.761904761904762
# Users with less than 10 interactions: 75
# Age: 18.0
# Number of user profiles: 109
# Average items in user profile: 5.238532110091743
# Users with less than 10 interactions: 96
# Age: 19.0
# Number of user profiles: 73
# Average items in user profile: 3.73972602739726
# Users with less than 10 interactions: 68
# Age: 20.0
# Number of user profiles: 99
# Average items in user profile: 3.5555555555555554
# Users with less than 10 interactions: 91
# Age: 21.0
# Number of user profiles: 119
# Average items in user profile: 5.151260504201681
# Users with less than 10 interactions: 109
# Age: 22.0
# Number of user profiles: 121
# Average items in user profile: 5.702479338842975
# Users with less than 10 interactions: 105
# Age: 23.0
# Number of user profiles: 205
# Average items in user profile: 5.380487804878049
# Users with less than 10 interactions: 181
# Age: 24.0
# Number of user profiles: 193
# Average items in user profile: 6.196891191709844
# Users with less than 10 interactions: 169
# Age: 25.0
# Number of user profiles: 221
# Average items in user profile: 6.226244343891403
# Users with less than 10 interactions: 183
# Age: 26.0
# Number of user profiles: 240
# Average items in user profile: 5.791666666666667
# Users with less than 10 interactions: 199
# Age: 27.0
# Number of user profiles: 219
# Average items in user profile: 5.9771689497716896
# Users with less than 10 interactions: 184
# Age: 28.0
# Number of user profiles: 236
# Average items in user profile: 6.953389830508475
# Users with less than 10 interactions: 195
# Age: 29.0
# Number of user profiles: 304
# Average items in user profile: 6.690789473684211
# Users with less than 10 interactions: 258
# Age: 30.0
# Number of user profiles: 240
# Average items in user profile: 7.595833333333333
# Users with less than 10 interactions: 197
# Age: 31.0
# Number of user profiles: 231
# Average items in user profile: 6.744588744588745
# Users with less than 10 interactions: 193
# Age: 32.0
# Number of user profiles: 255
# Average items in user profile: 7.207843137254902
# Users with less than 10 interactions: 213
# Age: 33.0
# Number of user profiles: 247
# Average items in user profile: 10.210526315789474
# Users with less than 10 interactions: 204
# Age: 34.0
# Number of user profiles: 250
# Average items in user profile: 6.372
# Users with less than 10 interactions: 215
# Age: 35.0
# Number of user profiles: 227
# Average items in user profile: 5.541850220264317
# Users with less than 10 interactions: 192
# Age: 36.0
# Number of user profiles: 219
# Average items in user profile: 8.251141552511415
# Users with less than 10 interactions: 180
# Age: 37.0
# Number of user profiles: 202
# Average items in user profile: 7.297029702970297
# Users with less than 10 interactions: 171
# Age: 38.0
# Number of user profiles: 198
# Average items in user profile: 7.737373737373737
# Users with less than 10 interactions: 165
# Age: 39.0
# Number of user profiles: 164
# Average items in user profile: 6.695121951219512
# Users with less than 10 interactions: 138
# Age: 40.0
# Number of user profiles: 152
# Average items in user profile: 6.1118421052631575
# Users with less than 10 interactions: 129
# Age: 41.0
# Number of user profiles: 161
# Average items in user profile: 6.75776397515528
# Users with less than 10 interactions: 135
# Age: 42.0
# Number of user profiles: 133
# Average items in user profile: 4.503759398496241
# Users with less than 10 interactions: 121
# Age: 43.0
# Number of user profiles: 156
# Average items in user profile: 8.282051282051283
# Users with less than 10 interactions: 130
# Age: 44.0
# Number of user profiles: 134
# Average items in user profile: 9.649253731343284
# Users with less than 10 interactions: 118
# Age: 45.0
# Number of user profiles: 114
# Average items in user profile: 6.342105263157895
# Users with less than 10 interactions: 100
# Age: 46.0
# Number of user profiles: 111
# Average items in user profile: 9.585585585585585
# Users with less than 10 interactions: 91
# Age: 47.0
# Number of user profiles: 109
# Average items in user profile: 11.412844036697248
# Users with less than 10 interactions: 88
# Age: 48.0
# Number of user profiles: 93
# Average items in user profile: 5.505376344086022
# Users with less than 10 interactions: 79
# Age: 49.0
# Number of user profiles: 117
# Average items in user profile: 8.316239316239317
# Users with less than 10 interactions: 99
# Age: 50.0
# Number of user profiles: 100
# Average items in user profile: 4.89
# Users with less than 10 interactions: 87
# Age: 51.0
# Number of user profiles: 91
# Average items in user profile: 11.032967032967033
# Users with less than 10 interactions: 74
# Age: 52.0
# Number of user profiles: 94
# Average items in user profile: 10.26595744680851
# Users with less than 10 interactions: 81
# Age: 53.0
# Number of user profiles: 91
# Average items in user profile: 4.7032967032967035
# Users with less than 10 interactions: 80
# Age: 54.0
# Number of user profiles: 101
# Average items in user profile: 6.900990099009901
# Users with less than 10 interactions: 89
# Age: 55.0
# Number of user profiles: 75
# Average items in user profile: 5.0
# Users with less than 10 interactions: 66
# Age: 56.0
# Number of user profiles: 73
# Average items in user profile: 5.7534246575342465
# Users with less than 10 interactions: 66
# Age: 57.0
# Number of user profiles: 102
# Average items in user profile: 5.333333333333333
# Users with less than 10 interactions: 90
# Age: 58.0
# Number of user profiles: 72
# Average items in user profile: 10.38888888888889
# Users with less than 10 interactions: 66
# Age: 59.0
# Number of user profiles: 55
# Average items in user profile: 3.090909090909091
# Users with less than 10 interactions: 52
# Age: 60.0
# Number of user profiles: 45
# Average items in user profile: 4.933333333333334
# Users with less than 10 interactions: 41
# Age: 61.0
# Number of user profiles: 44
# Average items in user profile: 7.431818181818182
# Users with less than 10 interactions: 38
# Age: 62.0
# Number of user profiles: 40
# Average items in user profile: 10.55
# Users with less than 10 interactions: 37
# Age: 63.0
# Number of user profiles: 28
# Average items in user profile: 6.928571428571429
# Users with less than 10 interactions: 25
# Age: 64.0
# Number of user profiles: 21
# Average items in user profile: 1.7619047619047619
# Users with less than 10 interactions: 21
#
#
# Test set
# Age: 12.0
# Number of user profiles: 15
# Average items in user profile: 4.533333333333333
# Users with less than 10 listening events: 13
# Age: 13.0
# Number of user profiles: 23
# Average items in user profile: 3.782608695652174
# Users with less than 10 listening events: 22
# Age: 14.0
# Number of user profiles: 44
# Average items in user profile: 6.0
# Users with less than 10 listening events: 38
# Age: 15.0
# Number of user profiles: 47
# Average items in user profile: 4.446808510638298
# Users with less than 10 listening events: 41
# Age: 16.0
# Number of user profiles: 53
# Average items in user profile: 3.9245283018867925
# Users with less than 10 listening events: 50
# Age: 17.0
# Number of user profiles: 84
# Average items in user profile: 4.714285714285714
# Users with less than 10 listening events: 75
# Age: 18.0
# Number of user profiles: 109
# Average items in user profile: 6.321100917431193
# Users with less than 10 listening events: 95
# Age: 19.0
# Number of user profiles: 73
# Average items in user profile: 4.835616438356165
# Users with less than 10 listening events: 68
# Age: 20.0
# Number of user profiles: 99
# Average items in user profile: 4.545454545454546
# Users with less than 10 listening events: 87
# Age: 21.0
# Number of user profiles: 119
# Average items in user profile: 6.142857142857143
# Users with less than 10 listening events: 107
# Age: 22.0
# Number of user profiles: 121
# Average items in user profile: 6.75206611570248
# Users with less than 10 listening events: 104
# Age: 23.0
# Number of user profiles: 205
# Average items in user profile: 6.385365853658537
# Users with less than 10 listening events: 177
# Age: 24.0
# Number of user profiles: 193
# Average items in user profile: 7.217616580310881
# Users with less than 10 listening events: 163
# Age: 25.0
# Number of user profiles: 221
# Average items in user profile: 7.221719457013575
# Users with less than 10 listening events: 179
# Age: 26.0
# Number of user profiles: 240
# Average items in user profile: 6.875
# Users with less than 10 listening events: 193
# Age: 27.0
# Number of user profiles: 219
# Average items in user profile: 7.0867579908675795
# Users with less than 10 listening events: 178
# Age: 28.0
# Number of user profiles: 236
# Average items in user profile: 7.9576271186440675
# Users with less than 10 listening events: 192
# Age: 29.0
# Number of user profiles: 304
# Average items in user profile: 7.7631578947368425
# Users with less than 10 listening events: 256
# Age: 30.0
# Number of user profiles: 240
# Average items in user profile: 8.625
# Users with less than 10 listening events: 194
# Age: 31.0
# Number of user profiles: 231
# Average items in user profile: 7.8268398268398265
# Users with less than 10 listening events: 189
# Age: 32.0
# Number of user profiles: 255
# Average items in user profile: 8.223529411764705
# Users with less than 10 listening events: 208
# Age: 33.0
# Number of user profiles: 247
# Average items in user profile: 11.287449392712551
# Users with less than 10 listening events: 196
# Age: 34.0
# Number of user profiles: 250
# Average items in user profile: 7.5
# Users with less than 10 listening events: 206
# Age: 35.0
# Number of user profiles: 227
# Average items in user profile: 6.682819383259912
# Users with less than 10 listening events: 189
# Age: 36.0
# Number of user profiles: 219
# Average items in user profile: 9.255707762557078
# Users with less than 10 listening events: 177
# Age: 37.0
# Number of user profiles: 202
# Average items in user profile: 8.326732673267326
# Users with less than 10 listening events: 168
# Age: 38.0
# Number of user profiles: 198
# Average items in user profile: 8.757575757575758
# Users with less than 10 listening events: 160
# Age: 39.0
# Number of user profiles: 164
# Average items in user profile: 7.682926829268292
# Users with less than 10 listening events: 132
# Age: 40.0
# Number of user profiles: 152
# Average items in user profile: 7.1381578947368425
# Users with less than 10 listening events: 126
# Age: 41.0
# Number of user profiles: 161
# Average items in user profile: 7.875776397515528
# Users with less than 10 listening events: 135
# Age: 42.0
# Number of user profiles: 133
# Average items in user profile: 5.518796992481203
# Users with less than 10 listening events: 114
# Age: 43.0
# Number of user profiles: 156
# Average items in user profile: 9.35897435897436
# Users with less than 10 listening events: 128
# Age: 44.0
# Number of user profiles: 134
# Average items in user profile: 10.694029850746269
# Users with less than 10 listening events: 113
# Age: 45.0
# Number of user profiles: 114
# Average items in user profile: 7.43859649122807
# Users with less than 10 listening events: 100
# Age: 46.0
# Number of user profiles: 111
# Average items in user profile: 10.495495495495495
# Users with less than 10 listening events: 89
# Age: 47.0
# Number of user profiles: 109
# Average items in user profile: 12.46788990825688
# Users with less than 10 listening events: 87
# Age: 48.0
# Number of user profiles: 93
# Average items in user profile: 6.56989247311828
# Users with less than 10 listening events: 78
# Age: 49.0
# Number of user profiles: 117
# Average items in user profile: 9.393162393162394
# Users with less than 10 listening events: 98
# Age: 50.0
# Number of user profiles: 100
# Average items in user profile: 5.95
# Users with less than 10 listening events: 84
# Age: 51.0
# Number of user profiles: 91
# Average items in user profile: 12.142857142857142
# Users with less than 10 listening events: 73
# Age: 52.0
# Number of user profiles: 94
# Average items in user profile: 11.27659574468085
# Users with less than 10 listening events: 78
# Age: 53.0
# Number of user profiles: 91
# Average items in user profile: 5.802197802197802
# Users with less than 10 listening events: 80
# Age: 54.0
# Number of user profiles: 101
# Average items in user profile: 7.96039603960396
# Users with less than 10 listening events: 88
# Age: 55.0
# Number of user profiles: 75
# Average items in user profile: 6.026666666666666
# Users with less than 10 listening events: 66
# Age: 56.0
# Number of user profiles: 73
# Average items in user profile: 6.917808219178082
# Users with less than 10 listening events: 64
# Age: 57.0
# Number of user profiles: 102
# Average items in user profile: 6.2745098039215685
# Users with less than 10 listening events: 90
# Age: 58.0
# Number of user profiles: 72
# Average items in user profile: 11.36111111111111
# Users with less than 10 listening events: 66
# Age: 59.0
# Number of user profiles: 55
# Average items in user profile: 4.036363636363636
# Users with less than 10 listening events: 52
# Age: 60.0
# Number of user profiles: 45
# Average items in user profile: 6.0
# Users with less than 10 listening events: 40
# Age: 61.0
# Number of user profiles: 44
# Average items in user profile: 8.477272727272727
# Users with less than 10 listening events: 38
# Age: 62.0
# Number of user profiles: 40
# Average items in user profile: 11.45
# Users with less than 10 listening events: 36
# Age: 63.0
# Number of user profiles: 28
# Average items in user profile: 7.821428571428571
# Users with less than 10 listening events: 25
# Age: 64.0
# Number of user profiles: 21
# Average items in user profile: 2.761904761904762
# Users with less than 10 listening events: 21

# %%
sparsity = 1 - (len_interactions / (len(users) * len(users)))
print(sparsity)
# Out:
# 0.9949678366675325
