# %% [markdown]
# # Analyze train/validation/test set
# Run the cells to analyze the age distributions and number of interactions generated by the split sets.

# %%
import pandas as pd
import os
from dotenv import load_dotenv
from pathlib import Path
env_path = Path('../..') / 'config.env'
load_dotenv(dotenv_path=env_path)
dataset_dir = os.getenv("dataset_directory")

# %%
dataset = 'mlhd' # ml, mlhd, or bx
filtered = True

# %%
if dataset == 'ml':
    data_dir = dataset_dir + f'/processed/ml_rec{"_filtered" if filtered else ""}'
elif dataset == 'mlhd':
    data_dir = dataset_dir + f'/processed/mlhd_rec{"_filtered" if filtered else ""}'
elif dataset == 'bx':
    data_dir = dataset_dir + f'/processed/bx_rec{"_filtered" if filtered else ""}'

# %%
train_path = data_dir + f'/train.tsv'
validation_path = data_dir + f'/validation.tsv'
test_path = data_dir + f'/test.tsv'
user_info_path = data_dir + f'/user_info.tsv'

column_names = ['user_id', 'item_id', 'count'] if dataset == 'bx' else ['user_id', 'item_id', 'count', 'timestamp']

train = pd.read_csv(train_path, sep='\t', header=None, names=column_names)
validation = pd.read_csv(validation_path, sep='\t', header=None, names=column_names)
test = pd.read_csv(test_path, sep='\t', header=None, names=column_names)

users = pd.read_csv(user_info_path, sep='\t')


train = pd.merge(train, users, on='user_id', how='inner')
validation = pd.merge(validation, users, on='user_id', how='inner')
test = pd.merge(test, users, on='user_id', how='inner')

# %%
len_interactions = len(train) + len(validation) + len(test)

print(f'Train set: {len(train)} rows; {len(train) / len_interactions * 100:.2f}% of total interactions')
print(f'Validation set: {len(validation)} rows; {len(validation) / len_interactions * 100:.2f}% of total interactions')
print(f'Test set: {len(test)} rows; {len(test) / len_interactions * 100:.2f}% of total interactions')

print(f'Train set: {len(train["user_id"].unique())} unique users')
print(f'Validation set: {len(validation["user_id"].unique())} unique users')
print(f'Test set: {len(test["user_id"].unique())} unique users')

train_interactions_per_user = train.groupby('user_id').size()
print(f'Train set: {train_interactions_per_user.mean()} average interactions per user')

validation_interactions_per_user = validation.groupby('user_id').size()
print(f'Validation set: {validation_interactions_per_user.mean()} average interactions per user')

test_interactions_per_user = test.groupby('user_id').size()
print(f'Test set: {test_interactions_per_user.mean()} average interactions per user')
# Out:
# Train set: 11743489 rows; 78.79% of total interactions
# Validation set: 1988948 rows; 13.34% of total interactions
# Test set: 1171649 rows; 7.86% of total interactions
# Train set: 32572 unique users
# Validation set: 32572 unique users
# Test set: 32572 unique users
# Train set: 360.53938965983053 average interactions per user
# Validation set: 61.0631216996193 average interactions per user
# Test set: 35.97104875353064 average interactions per user

# %%
num_items = len(train['track_id'].unique())
print(f'Number of unique items in train set: {num_items}')
# Out:
# Number of unique items in train set: 207603

# %%
age_identifier = 'age_at_interaction' if dataset == 'mlhd' else 'age'
train_interactions_per_age_group = train.groupby(age_identifier)

validation_interactions_per_age_group = validation.groupby(age_identifier)

test_interactions_per_age_group = test.groupby(age_identifier)

# %%
empty_train_profiles = users[users['user_id'].isin(train['user_id']) == False]
empty_validation_profiles = users[users['user_id'].isin(validation['user_id']) == False]
empty_test_profiles = users[users['user_id'].isin(test['user_id']) == False]

print(f'Train set: {len(empty_train_profiles)} users with empty profiles')
print(f'Validation set: {len(empty_validation_profiles)} users with empty profiles')
print(f'Test set: {len(empty_test_profiles)} users with empty profiles')

small_user_profiles = train_interactions_per_user[train_interactions_per_user < 10]
print(f'Train set: {len(small_user_profiles)} users with less than 10 interactions')
small_user_profiles = validation_interactions_per_user[validation_interactions_per_user < 10]
print(f'Validation set: {len(small_user_profiles)} users with less than 10 interactions')
small_user_profiles = test_interactions_per_user[test_interactions_per_user < 10]
print(f'Test set: {len(small_user_profiles)} users with less than 10 interactions')
# Out:
# Train set: 0 users with empty profiles
# Validation set: 0 users with empty profiles
# Test set: 0 users with empty profiles
# Train set: 358 users with less than 10 interactions
# Validation set: 3455 users with less than 10 interactions
# Test set: 7148 users with less than 10 interactions

# %%
print("Train set")
for age, group in train_interactions_per_age_group:
    print(f'Age: {age}')
    print(f'Number of user profiles: {len(group["user_id"].unique())}')
    print(f'Average items in user profile: {group.groupby("user_id").size().mean()}')
    small_user_profiles = group.groupby("user_id").size()[group.groupby("user_id").size() < 10]
    print(f'Users with less than 10 interactions: {len(small_user_profiles)}')
print()
print()

print("Validation set")
for age, group in validation_interactions_per_age_group:
    print(f'Age: {age}')
    print(f'Number of user profiles: {len(group["user_id"].unique())}')
    print(f'Average items in user profile: {group.groupby("user_id").size().mean()}')
    small_user_profiles = group.groupby("user_id").size()[group.groupby("user_id").size() < 10]
    print(f'Users with less than 10 interactions: {len(small_user_profiles)}')
print()
print()   

print("Test set")
for age, group in test_interactions_per_age_group:
    print(f'Age: {age}')
    print(f'Number of user profiles: {len(group["user_id"].unique())}')
    print(f'Average items in user profile: {group.groupby("user_id").size().mean()}')
    small_user_profiles = group.groupby("user_id").size()[group.groupby("user_id").size() < 10]
    print(f'Users with less than 10 listening events: {len(small_user_profiles)}')
print()
print()
# Out:
# Train set
# Age: 12.0
# Number of user profiles: 134
# Average items in user profile: 291.3134328358209
# Users with less than 10 interactions: 2
# Age: 13.0
# Number of user profiles: 456
# Average items in user profile: 301.140350877193
# Users with less than 10 interactions: 8
# Age: 14.0
# Number of user profiles: 995
# Average items in user profile: 341.3819095477387
# Users with less than 10 interactions: 12
# Age: 15.0
# Number of user profiles: 1807
# Average items in user profile: 377.9894853348091
# Users with less than 10 interactions: 21
# Age: 16.0
# Number of user profiles: 2528
# Average items in user profile: 376.38805379746833
# Users with less than 10 interactions: 22
# Age: 17.0
# Number of user profiles: 3126
# Average items in user profile: 384.5403071017274
# Users with less than 10 interactions: 28
# Age: 18.0
# Number of user profiles: 3382
# Average items in user profile: 373.5198107628622
# Users with less than 10 interactions: 39
# Age: 19.0
# Number of user profiles: 3253
# Average items in user profile: 372.5539501998156
# Users with less than 10 interactions: 29
# Age: 20.0
# Number of user profiles: 2831
# Average items in user profile: 363.31614270575767
# Users with less than 10 interactions: 29
# Age: 21.0
# Number of user profiles: 2361
# Average items in user profile: 348.6488775942397
# Users with less than 10 interactions: 30
# Age: 22.0
# Number of user profiles: 2037
# Average items in user profile: 359.57142857142856
# Users with less than 10 interactions: 24
# Age: 23.0
# Number of user profiles: 1685
# Average items in user profile: 358.8160237388724
# Users with less than 10 interactions: 22
# Age: 24.0
# Number of user profiles: 1375
# Average items in user profile: 358.3541818181818
# Users with less than 10 interactions: 11
# Age: 25.0
# Number of user profiles: 1116
# Average items in user profile: 355.9453405017921
# Users with less than 10 interactions: 10
# Age: 26.0
# Number of user profiles: 938
# Average items in user profile: 351.43603411513857
# Users with less than 10 interactions: 14
# Age: 27.0
# Number of user profiles: 747
# Average items in user profile: 343.99196787148594
# Users with less than 10 interactions: 8
# Age: 28.0
# Number of user profiles: 632
# Average items in user profile: 324.56962025316454
# Users with less than 10 interactions: 6
# Age: 29.0
# Number of user profiles: 513
# Average items in user profile: 324.82846003898635
# Users with less than 10 interactions: 7
# Age: 30.0
# Number of user profiles: 418
# Average items in user profile: 325.2248803827751
# Users with less than 10 interactions: 4
# Age: 31.0
# Number of user profiles: 339
# Average items in user profile: 336.95575221238937
# Users with less than 10 interactions: 3
# Age: 32.0
# Number of user profiles: 277
# Average items in user profile: 289.90613718411555
# Users with less than 10 interactions: 1
# Age: 33.0
# Number of user profiles: 252
# Average items in user profile: 344.04761904761904
# Users with less than 10 interactions: 6
# Age: 34.0
# Number of user profiles: 199
# Average items in user profile: 336.2613065326633
# Users with less than 10 interactions: 4
# Age: 35.0
# Number of user profiles: 173
# Average items in user profile: 335.36416184971097
# Users with less than 10 interactions: 2
# Age: 36.0
# Number of user profiles: 144
# Average items in user profile: 338.05555555555554
# Users with less than 10 interactions: 2
# Age: 37.0
# Number of user profiles: 148
# Average items in user profile: 335.72297297297297
# Users with less than 10 interactions: 2
# Age: 38.0
# Number of user profiles: 120
# Average items in user profile: 364.14166666666665
# Users with less than 10 interactions: 1
# Age: 39.0
# Number of user profiles: 90
# Average items in user profile: 370.8666666666667
# Users with less than 10 interactions: 2
# Age: 40.0
# Number of user profiles: 70
# Average items in user profile: 404.2142857142857
# Users with less than 10 interactions: 0
# Age: 41.0
# Number of user profiles: 59
# Average items in user profile: 299.50847457627117
# Users with less than 10 interactions: 1
# Age: 42.0
# Number of user profiles: 59
# Average items in user profile: 394.59322033898303
# Users with less than 10 interactions: 0
# Age: 43.0
# Number of user profiles: 52
# Average items in user profile: 269.15384615384613
# Users with less than 10 interactions: 2
# Age: 44.0
# Number of user profiles: 38
# Average items in user profile: 336.2105263157895
# Users with less than 10 interactions: 0
# Age: 45.0
# Number of user profiles: 32
# Average items in user profile: 292.46875
# Users with less than 10 interactions: 0
# Age: 46.0
# Number of user profiles: 30
# Average items in user profile: 215.46666666666667
# Users with less than 10 interactions: 0
# Age: 47.0
# Number of user profiles: 23
# Average items in user profile: 369.0
# Users with less than 10 interactions: 1
# Age: 48.0
# Number of user profiles: 21
# Average items in user profile: 304.9047619047619
# Users with less than 10 interactions: 1
# Age: 49.0
# Number of user profiles: 13
# Average items in user profile: 341.84615384615387
# Users with less than 10 interactions: 0
# Age: 50.0
# Number of user profiles: 14
# Average items in user profile: 201.71428571428572
# Users with less than 10 interactions: 0
# Age: 51.0
# Number of user profiles: 16
# Average items in user profile: 276.25
# Users with less than 10 interactions: 1
# Age: 52.0
# Number of user profiles: 13
# Average items in user profile: 273.84615384615387
# Users with less than 10 interactions: 0
# Age: 53.0
# Number of user profiles: 10
# Average items in user profile: 394.0
# Users with less than 10 interactions: 0
# Age: 54.0
# Number of user profiles: 11
# Average items in user profile: 515.2727272727273
# Users with less than 10 interactions: 0
# Age: 55.0
# Number of user profiles: 6
# Average items in user profile: 245.0
# Users with less than 10 interactions: 0
# Age: 56.0
# Number of user profiles: 7
# Average items in user profile: 437.14285714285717
# Users with less than 10 interactions: 0
# Age: 57.0
# Number of user profiles: 10
# Average items in user profile: 340.0
# Users with less than 10 interactions: 1
# Age: 58.0
# Number of user profiles: 8
# Average items in user profile: 146.75
# Users with less than 10 interactions: 1
# Age: 59.0
# Number of user profiles: 4
# Average items in user profile: 84.25
# Users with less than 10 interactions: 1
#
#
# Validation set
# Age: 12.0
# Number of user profiles: 134
# Average items in user profile: 57.75373134328358
# Users with less than 10 interactions: 19
# Age: 13.0
# Number of user profiles: 456
# Average items in user profile: 56.56359649122807
# Users with less than 10 interactions: 54
# Age: 14.0
# Number of user profiles: 995
# Average items in user profile: 56.846231155778895
# Users with less than 10 interactions: 125
# Age: 15.0
# Number of user profiles: 1807
# Average items in user profile: 60.4803541781959
# Users with less than 10 interactions: 171
# Age: 16.0
# Number of user profiles: 2528
# Average items in user profile: 63.27017405063291
# Users with less than 10 interactions: 224
# Age: 17.0
# Number of user profiles: 3126
# Average items in user profile: 65.05502239283429
# Users with less than 10 interactions: 288
# Age: 18.0
# Number of user profiles: 3382
# Average items in user profile: 64.5357776463631
# Users with less than 10 interactions: 305
# Age: 19.0
# Number of user profiles: 3253
# Average items in user profile: 64.58223178604365
# Users with less than 10 interactions: 316
# Age: 20.0
# Number of user profiles: 2831
# Average items in user profile: 62.14341222182974
# Users with less than 10 interactions: 264
# Age: 21.0
# Number of user profiles: 2361
# Average items in user profile: 58.5429902583651
# Users with less than 10 interactions: 248
# Age: 22.0
# Number of user profiles: 2037
# Average items in user profile: 61.48306332842415
# Users with less than 10 interactions: 211
# Age: 23.0
# Number of user profiles: 1685
# Average items in user profile: 60.37744807121662
# Users with less than 10 interactions: 192
# Age: 24.0
# Number of user profiles: 1375
# Average items in user profile: 59.66981818181818
# Users with less than 10 interactions: 177
# Age: 25.0
# Number of user profiles: 1116
# Average items in user profile: 59.12455197132616
# Users with less than 10 interactions: 124
# Age: 26.0
# Number of user profiles: 938
# Average items in user profile: 59.46162046908316
# Users with less than 10 interactions: 118
# Age: 27.0
# Number of user profiles: 747
# Average items in user profile: 53.68406961178046
# Users with less than 10 interactions: 98
# Age: 28.0
# Number of user profiles: 632
# Average items in user profile: 60.254746835443036
# Users with less than 10 interactions: 80
# Age: 29.0
# Number of user profiles: 513
# Average items in user profile: 55.27095516569201
# Users with less than 10 interactions: 71
# Age: 30.0
# Number of user profiles: 418
# Average items in user profile: 54.143540669856456
# Users with less than 10 interactions: 56
# Age: 31.0
# Number of user profiles: 339
# Average items in user profile: 54.10914454277286
# Users with less than 10 interactions: 44
# Age: 32.0
# Number of user profiles: 277
# Average items in user profile: 48.671480144404335
# Users with less than 10 interactions: 44
# Age: 33.0
# Number of user profiles: 252
# Average items in user profile: 61.142857142857146
# Users with less than 10 interactions: 32
# Age: 34.0
# Number of user profiles: 199
# Average items in user profile: 55.743718592964825
# Users with less than 10 interactions: 27
# Age: 35.0
# Number of user profiles: 173
# Average items in user profile: 54.589595375722546
# Users with less than 10 interactions: 19
# Age: 36.0
# Number of user profiles: 144
# Average items in user profile: 52.94444444444444
# Users with less than 10 interactions: 19
# Age: 37.0
# Number of user profiles: 148
# Average items in user profile: 58.13513513513514
# Users with less than 10 interactions: 19
# Age: 38.0
# Number of user profiles: 120
# Average items in user profile: 60.25833333333333
# Users with less than 10 interactions: 18
# Age: 39.0
# Number of user profiles: 90
# Average items in user profile: 55.78888888888889
# Users with less than 10 interactions: 12
# Age: 40.0
# Number of user profiles: 70
# Average items in user profile: 65.55714285714286
# Users with less than 10 interactions: 10
# Age: 41.0
# Number of user profiles: 59
# Average items in user profile: 48.54237288135593
# Users with less than 10 interactions: 12
# Age: 42.0
# Number of user profiles: 59
# Average items in user profile: 70.38983050847457
# Users with less than 10 interactions: 10
# Age: 43.0
# Number of user profiles: 52
# Average items in user profile: 46.55769230769231
# Users with less than 10 interactions: 6
# Age: 44.0
# Number of user profiles: 38
# Average items in user profile: 49.026315789473685
# Users with less than 10 interactions: 7
# Age: 45.0
# Number of user profiles: 32
# Average items in user profile: 60.65625
# Users with less than 10 interactions: 5
# Age: 46.0
# Number of user profiles: 30
# Average items in user profile: 44.6
# Users with less than 10 interactions: 6
# Age: 47.0
# Number of user profiles: 23
# Average items in user profile: 54.608695652173914
# Users with less than 10 interactions: 3
# Age: 48.0
# Number of user profiles: 21
# Average items in user profile: 35.285714285714285
# Users with less than 10 interactions: 3
# Age: 49.0
# Number of user profiles: 13
# Average items in user profile: 71.0
# Users with less than 10 interactions: 2
# Age: 50.0
# Number of user profiles: 14
# Average items in user profile: 33.785714285714285
# Users with less than 10 interactions: 4
# Age: 51.0
# Number of user profiles: 16
# Average items in user profile: 84.3125
# Users with less than 10 interactions: 0
# Age: 52.0
# Number of user profiles: 13
# Average items in user profile: 38.15384615384615
# Users with less than 10 interactions: 2
# Age: 53.0
# Number of user profiles: 10
# Average items in user profile: 59.4
# Users with less than 10 interactions: 1
# Age: 54.0
# Number of user profiles: 11
# Average items in user profile: 82.0
# Users with less than 10 interactions: 1
# Age: 55.0
# Number of user profiles: 6
# Average items in user profile: 40.166666666666664
# Users with less than 10 interactions: 2
# Age: 56.0
# Number of user profiles: 7
# Average items in user profile: 80.28571428571429
# Users with less than 10 interactions: 1
# Age: 57.0
# Number of user profiles: 10
# Average items in user profile: 48.5
# Users with less than 10 interactions: 1
# Age: 58.0
# Number of user profiles: 8
# Average items in user profile: 33.625
# Users with less than 10 interactions: 3
# Age: 59.0
# Number of user profiles: 4
# Average items in user profile: 25.75
# Users with less than 10 interactions: 1
#
#
# Test set
# Age: 12.0
# Number of user profiles: 134
# Average items in user profile: 34.59701492537314
# Users with less than 10 listening events: 29
# Age: 13.0
# Number of user profiles: 456
# Average items in user profile: 35.30921052631579
# Users with less than 10 listening events: 102
# Age: 14.0
# Number of user profiles: 995
# Average items in user profile: 34.41708542713568
# Users with less than 10 listening events: 212
# Age: 15.0
# Number of user profiles: 1807
# Average items in user profile: 36.43054786939679
# Users with less than 10 listening events: 343
# Age: 16.0
# Number of user profiles: 2528
# Average items in user profile: 38.64556962025316
# Users with less than 10 listening events: 483
# Age: 17.0
# Number of user profiles: 3126
# Average items in user profile: 38.388355726167624
# Users with less than 10 listening events: 588
# Age: 18.0
# Number of user profiles: 3382
# Average items in user profile: 38.014192785334124
# Users with less than 10 listening events: 626
# Age: 19.0
# Number of user profiles: 3253
# Average items in user profile: 38.00368890255149
# Users with less than 10 listening events: 661
# Age: 20.0
# Number of user profiles: 2831
# Average items in user profile: 37.25962557400212
# Users with less than 10 listening events: 607
# Age: 21.0
# Number of user profiles: 2361
# Average items in user profile: 35.00381194409149
# Users with less than 10 listening events: 548
# Age: 22.0
# Number of user profiles: 2037
# Average items in user profile: 36.249386352479135
# Users with less than 10 listening events: 443
# Age: 23.0
# Number of user profiles: 1685
# Average items in user profile: 35.34777448071217
# Users with less than 10 listening events: 392
# Age: 24.0
# Number of user profiles: 1375
# Average items in user profile: 35.537454545454544
# Users with less than 10 listening events: 340
# Age: 25.0
# Number of user profiles: 1116
# Average items in user profile: 33.33691756272401
# Users with less than 10 listening events: 289
# Age: 26.0
# Number of user profiles: 938
# Average items in user profile: 34.46908315565032
# Users with less than 10 listening events: 230
# Age: 27.0
# Number of user profiles: 747
# Average items in user profile: 30.784471218206157
# Users with less than 10 listening events: 206
# Age: 28.0
# Number of user profiles: 632
# Average items in user profile: 34.59335443037975
# Users with less than 10 listening events: 161
# Age: 29.0
# Number of user profiles: 513
# Average items in user profile: 31.760233918128655
# Users with less than 10 listening events: 123
# Age: 30.0
# Number of user profiles: 418
# Average items in user profile: 29.97846889952153
# Users with less than 10 listening events: 117
# Age: 31.0
# Number of user profiles: 339
# Average items in user profile: 29.20353982300885
# Users with less than 10 listening events: 100
# Age: 32.0
# Number of user profiles: 277
# Average items in user profile: 29.642599277978338
# Users with less than 10 listening events: 73
# Age: 33.0
# Number of user profiles: 252
# Average items in user profile: 34.32539682539682
# Users with less than 10 listening events: 68
# Age: 34.0
# Number of user profiles: 199
# Average items in user profile: 28.718592964824122
# Users with less than 10 listening events: 60
# Age: 35.0
# Number of user profiles: 173
# Average items in user profile: 28.31791907514451
# Users with less than 10 listening events: 47
# Age: 36.0
# Number of user profiles: 144
# Average items in user profile: 33.986111111111114
# Users with less than 10 listening events: 36
# Age: 37.0
# Number of user profiles: 148
# Average items in user profile: 35.16216216216216
# Users with less than 10 listening events: 37
# Age: 38.0
# Number of user profiles: 120
# Average items in user profile: 35.75833333333333
# Users with less than 10 listening events: 31
# Age: 39.0
# Number of user profiles: 90
# Average items in user profile: 26.466666666666665
# Users with less than 10 listening events: 27
# Age: 40.0
# Number of user profiles: 70
# Average items in user profile: 29.085714285714285
# Users with less than 10 listening events: 20
# Age: 41.0
# Number of user profiles: 59
# Average items in user profile: 26.677966101694917
# Users with less than 10 listening events: 16
# Age: 42.0
# Number of user profiles: 59
# Average items in user profile: 30.372881355932204
# Users with less than 10 listening events: 18
# Age: 43.0
# Number of user profiles: 52
# Average items in user profile: 23.096153846153847
# Users with less than 10 listening events: 18
# Age: 44.0
# Number of user profiles: 38
# Average items in user profile: 29.86842105263158
# Users with less than 10 listening events: 13
# Age: 45.0
# Number of user profiles: 32
# Average items in user profile: 22.4375
# Users with less than 10 listening events: 12
# Age: 46.0
# Number of user profiles: 30
# Average items in user profile: 24.666666666666668
# Users with less than 10 listening events: 14
# Age: 47.0
# Number of user profiles: 23
# Average items in user profile: 28.26086956521739
# Users with less than 10 listening events: 9
# Age: 48.0
# Number of user profiles: 21
# Average items in user profile: 22.857142857142858
# Users with less than 10 listening events: 9
# Age: 49.0
# Number of user profiles: 13
# Average items in user profile: 36.30769230769231
# Users with less than 10 listening events: 2
# Age: 50.0
# Number of user profiles: 14
# Average items in user profile: 22.285714285714285
# Users with less than 10 listening events: 6
# Age: 51.0
# Number of user profiles: 16
# Average items in user profile: 31.0
# Users with less than 10 listening events: 3
# Age: 52.0
# Number of user profiles: 13
# Average items in user profile: 14.846153846153847
# Users with less than 10 listening events: 6
# Age: 53.0
# Number of user profiles: 10
# Average items in user profile: 34.8
# Users with less than 10 listening events: 2
# Age: 54.0
# Number of user profiles: 11
# Average items in user profile: 38.18181818181818
# Users with less than 10 listening events: 3
# Age: 55.0
# Number of user profiles: 6
# Average items in user profile: 12.666666666666666
# Users with less than 10 listening events: 4
# Age: 56.0
# Number of user profiles: 7
# Average items in user profile: 36.57142857142857
# Users with less than 10 listening events: 1
# Age: 57.0
# Number of user profiles: 10
# Average items in user profile: 17.0
# Users with less than 10 listening events: 4
# Age: 58.0
# Number of user profiles: 8
# Average items in user profile: 12.0
# Users with less than 10 listening events: 6
# Age: 59.0
# Number of user profiles: 4
# Average items in user profile: 7.0
# Users with less than 10 listening events: 3

# %%
sparsity = 1 - (len_interactions / (len(users) * len(users)))
print(sparsity)
# Out:
# 0.9838616499542093
